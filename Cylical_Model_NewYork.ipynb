# %%
#STEP 1: Seeing if I can open this bad boy, simple test performed below with the all data dataFrame object, NYAllData
import pandas as pd

NYAllData = pd.read_csv('New_York_State_Statewide_COVID-19_Testing_20240306.csv')

NYAllData
# Out:
#          Test Date Geography Description Geography Level  Total New Positives  \
# 0       03/03/2024                Albany          COUNTY                    9
# 1       03/03/2024              Allegany          COUNTY                    2
# 2       03/03/2024                 Bronx          COUNTY                   51
# 3       03/03/2024                Broome          COUNTY                    3
# 4       03/03/2024           Cattaraugus          COUNTY                    1
# ...            ...                   ...             ...                  ...
# 106867  03/01/2020         New York City          REGION                    2
# 106868  03/01/2020         North Country          REGION                    0
# 106869  03/01/2020         Southern Tier          REGION                    0
# 106870  03/01/2020      Western New York          REGION                    0
# 106871  03/01/2020             STATEWIDE       STATEWIDE                    2
#
#         Total Cases Per 100k  Total Cases Per 100k (7-day avg)  \
# 0                       2.85                              2.80
# 1                       4.28                              2.45
# 2                       3.70                              5.99
# 3                       1.52                              3.19
# 4                       1.31                              2.43
# ...                      ...                               ...
# 106867                  0.02                              0.02
# 106868                  0.00                              0.00
# 106869                  0.00                              0.00
# 106870                  0.00                              0.00
# 106871                  0.01                              0.01
#
#         New Positives PCR  Cases Per 100k PCR  New Positives Antigen  \
# 0                       8                2.53                      1
# 1                       1                2.14                      1
# 2                      26                1.88                     25
# 3                       3                1.52                      0
# 4                       0                0.00                      1
# ...                   ...                 ...                    ...
# 106867                  2                0.02                      0
# 106868                  0                0.00                      0
# 106869                  0                0.00                      0
# 106870                  0                0.00                      0
# 106871                  2                0.01                      0
#
#         Cases Per 100k Antigen
# 0                         0.32
# 1                         2.14
# 2                         1.81
# 3                         0.00
# 4                         1.31
# ...                        ...
# 106867                    0.00
# 106868                    0.00
# 106869                    0.00
# 106870                    0.00
# 106871                    0.00
#
# [106872 rows x 10 columns]

# %%
#Selecting the appropriate rows
county = "Bronx"
#Now the selected row is the county
#This is determined based upon a boolean condition
#So now selected rows should contain the specific county data
NYAllData = NYAllData[NYAllData['Geography Description'] == county]

print(NYAllData)
# Out:
#          Test Date Geography Description Geography Level  Total New Positives  \
# 2       03/03/2024                 Bronx          COUNTY                   51
# 75      03/02/2024                 Bronx          COUNTY                   43
# 148     03/01/2024                 Bronx          COUNTY                   81
# 221     02/29/2024                 Bronx          COUNTY                   77
# 294     02/28/2024                 Bronx          COUNTY                   92
# ...            ...                   ...             ...                  ...
# 106509  03/05/2020                 Bronx          COUNTY                    0
# 106582  03/04/2020                 Bronx          COUNTY                    0
# 106655  03/03/2020                 Bronx          COUNTY                    0
# 106728  03/02/2020                 Bronx          COUNTY                    0
# 106801  03/01/2020                 Bronx          COUNTY                    1
#
#         Total Cases Per 100k  Total Cases Per 100k (7-day avg)  \
# 2                       3.70                              5.99
# 75                      3.12                              6.11
# 148                     5.87                              6.16
# 221                     5.58                              6.16
# 294                     6.67                              6.46
# ...                      ...                               ...
# 106509                  0.00                              0.01
# 106582                  0.00                              0.02
# 106655                  0.00                              0.02
# 106728                  0.00                              0.03
# 106801                  0.07                              0.07
#
#         New Positives PCR  Cases Per 100k PCR  New Positives Antigen  \
# 2                      26                1.88                     25
# 75                     23                1.67                     20
# 148                    53                3.84                     28
# 221                    49                3.55                     28
# 294                    51                3.70                     41
# ...                   ...                 ...                    ...
# 106509                  0                0.00                      0
# 106582                  0                0.00                      0
# 106655                  0                0.00                      0
# 106728                  0                0.00                      0
# 106801                  1                0.07                      0
#
#         Cases Per 100k Antigen
# 2                         1.81
# 75                        1.45
# 148                       2.03
# 221                       2.03
# 294                       2.97
# ...                        ...
# 106509                    0.00
# 106582                    0.00
# 106655                    0.00
# 106728                    0.00
# 106801                    0.00
#
# [1464 rows x 10 columns]

# %%
#Step 3: Let us convert that 'Test Date' data into date time
#Note, some warning is provided, but I do not think that will be of concern
NYAllData['Test Date +'] = pd.to_datetime(NYAllData['Test Date'])

NYAllData
# Out:
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_23080\628639892.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NYAllData['Test Date +'] = pd.to_datetime(NYAllData['Test Date'])
#          Test Date Geography Description Geography Level  Total New Positives  \
# 2       03/03/2024                 Bronx          COUNTY                   51
# 75      03/02/2024                 Bronx          COUNTY                   43
# 148     03/01/2024                 Bronx          COUNTY                   81
# 221     02/29/2024                 Bronx          COUNTY                   77
# 294     02/28/2024                 Bronx          COUNTY                   92
# ...            ...                   ...             ...                  ...
# 106509  03/05/2020                 Bronx          COUNTY                    0
# 106582  03/04/2020                 Bronx          COUNTY                    0
# 106655  03/03/2020                 Bronx          COUNTY                    0
# 106728  03/02/2020                 Bronx          COUNTY                    0
# 106801  03/01/2020                 Bronx          COUNTY                    1
#
#         Total Cases Per 100k  Total Cases Per 100k (7-day avg)  \
# 2                       3.70                              5.99
# 75                      3.12                              6.11
# 148                     5.87                              6.16
# 221                     5.58                              6.16
# 294                     6.67                              6.46
# ...                      ...                               ...
# 106509                  0.00                              0.01
# 106582                  0.00                              0.02
# 106655                  0.00                              0.02
# 106728                  0.00                              0.03
# 106801                  0.07                              0.07
#
#         New Positives PCR  Cases Per 100k PCR  New Positives Antigen  \
# 2                      26                1.88                     25
# 75                     23                1.67                     20
# 148                    53                3.84                     28
# 221                    49                3.55                     28
# 294                    51                3.70                     41
# ...                   ...                 ...                    ...
# 106509                  0                0.00                      0
# 106582                  0                0.00                      0
# 106655                  0                0.00                      0
# 106728                  0                0.00                      0
# 106801                  1                0.07                      0
#
#         Cases Per 100k Antigen Test Date +
# 2                         1.81  2024-03-03
# 75                        1.45  2024-03-02
# 148                       2.03  2024-03-01
# 221                       2.03  2024-02-29
# 294                       2.97  2024-02-28
# ...                        ...         ...
# 106509                    0.00  2020-03-05
# 106582                    0.00  2020-03-04
# 106655                    0.00  2020-03-03
# 106728                    0.00  2020-03-02
# 106801                    0.00  2020-03-01
#
# [1464 rows x 11 columns]

# %%
#Step 4: Building a model
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics


#doing something I read online to make this date time data actually usable
#What is basically has done is make Test Date now be the number of days since the start going from 0 (days 1) to the end (the final recored day)
#Very cheeky
NYAllData['Test Date +'] = np.arange(len(NYAllData))

print(NYAllData['Test Date +'])

#Adding a cosine feature
NYAllData['Cos'] = np.cos(2 * np.pi* NYAllData['Test Date +'] / 365)

X= NYAllData[['Test Date +','Cos']]
y = NYAllData['Total Cases Per 100k']

model = LinearRegression().fit(X,y)

NYAllData
# Out:
# 2            0
# 75           1
# 148          2
# 221          3
# 294          4
#           ...
# 106509    1459
# 106582    1460
# 106655    1461
# 106728    1462
# 106801    1463
# Name: Test Date +, Length: 1464, dtype: int32
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_23080\2033225055.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NYAllData['Test Date +'] = np.arange(len(NYAllData))
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_23080\2033225055.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NYAllData['Cos'] = np.cos(2 * np.pi* NYAllData['Test Date +'] / 365)
#          Test Date Geography Description Geography Level  Total New Positives  \
# 2       03/03/2024                 Bronx          COUNTY                   51
# 75      03/02/2024                 Bronx          COUNTY                   43
# 148     03/01/2024                 Bronx          COUNTY                   81
# 221     02/29/2024                 Bronx          COUNTY                   77
# 294     02/28/2024                 Bronx          COUNTY                   92
# ...            ...                   ...             ...                  ...
# 106509  03/05/2020                 Bronx          COUNTY                    0
# 106582  03/04/2020                 Bronx          COUNTY                    0
# 106655  03/03/2020                 Bronx          COUNTY                    0
# 106728  03/02/2020                 Bronx          COUNTY                    0
# 106801  03/01/2020                 Bronx          COUNTY                    1
#
#         Total Cases Per 100k  Total Cases Per 100k (7-day avg)  \
# 2                       3.70                              5.99
# 75                      3.12                              6.11
# 148                     5.87                              6.16
# 221                     5.58                              6.16
# 294                     6.67                              6.46
# ...                      ...                               ...
# 106509                  0.00                              0.01
# 106582                  0.00                              0.02
# 106655                  0.00                              0.02
# 106728                  0.00                              0.03
# 106801                  0.07                              0.07
#
#         New Positives PCR  Cases Per 100k PCR  New Positives Antigen  \
# 2                      26                1.88                     25
# 75                     23                1.67                     20
# 148                    53                3.84                     28
# 221                    49                3.55                     28
# 294                    51                3.70                     41
# ...                   ...                 ...                    ...
# 106509                  0                0.00                      0
# 106582                  0                0.00                      0
# 106655                  0                0.00                      0
# 106728                  0                0.00                      0
# 106801                  1                0.07                      0
#
#         Cases Per 100k Antigen  Test Date +       Cos
# 2                         1.81            0  1.000000
# 75                        1.45            1  0.999852
# 148                       2.03            2  0.999407
# 221                       2.03            3  0.998667
# 294                       2.97            4  0.997630
# ...                        ...          ...       ...
# 106509                    0.00         1459  0.999852
# 106582                    0.00         1460  1.000000
# 106655                    0.00         1461  0.999852
# 106728                    0.00         1462  0.999407
# 106801                    0.00         1463  0.998667
#
# [1464 rows x 12 columns]

# %%
#Plotting
#Added push comment to test git

print("Git hub test")

import matplotlib.pyplot as plt
import matplotlib.dates
from datetime import datetime

x_axis= pd.to_datetime(NYAllData['Test Date']) #This needed to be converted to a date time format to work, used CO-Pilot to help me with this
y = NYAllData['Total Cases Per 100k']


plt.xlim(datetime(2020,3,1), datetime(2024,3,3))
plt.ylim(0, 300)
plt.scatter(x_axis, y, color = 'green')

plt.plot(x_axis, model.predict(X), color="blue") #CO-Pilot added the model.predict(X) part, and I think I understand what it is doing
plt.xlabel("Test Date")
plt.ylabel("Total Cases Per 100k")
plt.show()
# Out:
# Git hub test
